# %%
import pathlib
import matplotlib

from hpctoolkit_dataframe import HPCtoolkitDataFrame

# %matplotlib inline

# %%
# %%time

df = HPCtoolkitDataFrame(path=pathlib.Path('test', 'data', 'experiment1.xml'), max_depth=None)
# Out:
# CPU times: user 3.03 s, sys: 32 ms, total: 3.06 s
# Wall time: 3.06 s

# %%
df.compact[::200]
# Out:
#        CPUTIME (usec):Mean (I)  CPUTIME (usec):Mean (I) ratio of total  \
# -1                  72135600.0                                1.000000
#  320                   63876.0                                0.000885
#  552                  271507.0                                0.003764
#  792                    7983.0                                0.000111
#  1029                   7947.0                                0.000110
#  1256                  15968.0                                0.000221
#  1485                   7973.0                                0.000111
#  1724                   7988.0                                0.000111
#  1942                 199605.0                                0.002767
#  2147                   7987.0                                0.000111
#  2359                  15972.0                                0.000221
#  2583                  31963.0                                0.000443
#  2801                  15989.0                                0.000222
#  3030                  15958.0                                0.000221
#  3270                  39940.0                                0.000554
#  3501                  15955.0                                0.000221
#  3730                  95798.0                                0.001328
#  3955                 351101.0                                0.004867
#
#        CPUTIME (usec):Mean (I) ratio of parent  module  \
# -1                                    1.000000     NaN
#  320                                  1.000000  flash4
#  552                                  0.723401  flash4
#  792                                  0.166458  flash4
#  1029                                 0.110767  flash4
#  1256                                 1.000000  flash4
#  1485                                 1.000000  flash4
#  1724                                 0.142852  flash4
#  1942                                 0.012090  flash4
#  2147                                 0.002299  flash4
#  2359                                 0.004598  flash4
#  2583                                 0.014502  flash4
#  2801                                 0.031257  flash4
#  3030                                 0.399810  flash4
#  3270                                 0.059552  flash4
#  3501                                 1.000000  flash4
#  3730                                 1.000000  flash4
#  3955                                 1.000000  flash4
#
#                                       file  line  \
# -1                                     NaN     0
#  320                  amr_perm_to_1blk.F90   134
#  552              Grid_renormAbundance.F90   103
#  792            gr_mpolePot3Dcartesian.F90   559
#  1029                   gr_bcGetRegion.F90   335
#  1256             Grid_bcApplyToRegion.F90   287
#  1485              Gravity_accelOneRow.F90   212
#  1724                   hy_eigenVector.F90   149
#  1942  hy_DataReconstructNormalDir_PPM.F90   606
#  2147               hy_getRiemannState.F90   988
#  2359               hy_getRiemannState.F90  1292
#  2583                 hy_unsplitUpdate.F90   460
#  2801           gr_mpolePot3Dcartesian.F90   560
#  3030                   gr_bcPutRegion.F90   271
#  3270           Multispecies_getSumInv.F90   133
#  3501            amr_1blk_cc_cp_remote.F90   216
#  3730            amr_1blk_cc_cp_remote.F90   216
#  3955                mpi_amr_guardcell.F90   380
#
#                               procedure             type
# -1                                  NaN             root
#  320                  amr_perm_to_1blk_             loop
#  552              grid_renormabundance_        statement
#  792            gr_mpolepot3dcartesian_        statement
#  1029                   gr_bcgetregion_        statement
#  1256             grid_bcapplytoregion_             loop
#  1485              gravity_accelonerow_  procedure frame
#  1724                   hy_eigenvector_        statement
#  1942  hy_datareconstructnormaldir_ppm_        statement
#  2147               hy_getriemannstate_        statement
#  2359               hy_getriemannstate_        statement
#  2583                 hy_unsplitupdate_        statement
#  2801           gr_mpolepot3dcartesian_        statement
#  3030                   gr_bcputregion_        statement
#  3270           multispecies_getsuminv_        statement
#  3501            amr_1blk_cc_cp_remote_             loop
#  3730            amr_1blk_cc_cp_remote_             loop
#  3955                    amr_guardcell_             loop

# %%
df.flame_graph()

# %%
df.hot_path().compact
# Out:
#        CPUTIME (usec):Mean (I)  CPUTIME (usec):Mean (I) ratio of total  \
# -1                  72135600.0                                1.000000
#  2                  72135600.0                                1.000000
#  4                  72135600.0                                1.000000
#  6                  72135600.0                                1.000000
#  797                68027100.0                                0.943045
#  798                68027100.0                                0.943045
#  813                61968000.0                                0.859049
#  1456               47754000.0                                0.662003
#  1477               47722000.0                                0.661560
#  1479               47722000.0                                0.661560
#  1512               34679300.0                                0.480752
#  1547               30974900.0                                0.429398
#  1548               30974900.0                                0.429398
#  1549               30974900.0                                0.429398
#  1563               30679400.0                                0.425302
#  1679               27795800.0                                0.385327
#  1690               26358800.0                                0.365406
#  1916               16509800.0                                0.228872
#
#        CPUTIME (usec):Mean (I) ratio of parent               module  \
# -1                                    1.000000                  NaN
#  2                                    1.000000  libmonitor.so.0.0.0
#  4                                    1.000000               flash4
#  6                                    1.000000               flash4
#  797                                  0.943045               flash4
#  798                                  1.000000               flash4
#  813                                  0.910931               flash4
#  1456                                 0.770624               flash4
#  1477                                 0.999330               flash4
#  1479                                 1.000000               flash4
#  1512                                 0.726694               flash4
#  1547                                 0.893181               flash4
#  1548                                 1.000000               flash4
#  1549                                 1.000000               flash4
#  1563                                 0.990460               flash4
#  1679                                 0.906009               flash4
#  1690                                 0.948302               flash4
#  1916                                 0.626349               flash4
#
#                                        file  line  \
# -1                                      NaN     0
#  2     <unknown file> [libmonitor.so.0.0.0]     0
#  4                                Flash.F90    43
#  6                                Flash.F90    40
#  797                 Driver_evolveFlash.F90    38
#  798                 Driver_evolveFlash.F90   164
#  813                              Hydro.F90     6
#  1456                        hy_advance.F90     5
#  1477                        hy_advance.F90    75
#  1479                  hy_computeFluxes.F90    78
#  1512                hy_getRiemannState.F90    68
#  1547                hy_getRiemannState.F90   474
#  1548                hy_getRiemannState.F90   476
#  1549                hy_getRiemannState.F90   477
#  1563             hy_dataReconstOneStep.F90    82
#  1679             hy_dataReconstOneStep.F90   485
#  1690   hy_DataReconstructNormalDir_PPM.F90    73
#  1916   hy_DataReconstructNormalDir_PPM.F90   593
#
#                               procedure             type
# -1                                  NaN             root
#  2                       <program root>  procedure frame
#  4                                 main  procedure frame
#  6                               MAIN__  procedure frame
#  797                driver_evolveflash_  procedure frame
#  798                driver_evolveflash_             loop
#  813                             hydro_  procedure frame
#  1456                       hy_advance_  procedure frame
#  1477                       hy_advance_             loop
#  1479                 hy_computefluxes_  procedure frame
#  1512               hy_getriemannstate_  procedure frame
#  1547               hy_getriemannstate_             loop
#  1548               hy_getriemannstate_             loop
#  1549               hy_getriemannstate_             loop
#  1563            hy_datareconstonestep_  procedure frame
#  1679            hy_datareconstonestep_             loop
#  1690  hy_datareconstructnormaldir_ppm_  procedure frame
#  1916  hy_datareconstructnormaldir_ppm_             loop

# %%
prefix = tuple(df.hot_path().compact[:10].index.values)
prefix
# Out:
# (-1, 2, 4, 6, 797, 798, 813, 1456, 1477, 1479)

# %%
df.flame_graph(prefix=prefix[1:])

# %%
df[df.procedure == 'hy_tvdslope_'][df.type == 'procedure frame'].compact
# Out:
# /home/mateusz/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       CPUTIME (usec):Mean (I)  CPUTIME (usec):Mean (I) ratio of total  \
# 1796                 175777.0                                0.002437
# 1814                 119770.0                                0.001660
# 1833                 135765.0                                0.001882
#
#       CPUTIME (usec):Mean (I) ratio of parent  module             file  line  \
# 1796                                 0.006669  flash4  hy_TVDslope.F90    54
# 1814                                 0.004544  flash4  hy_TVDslope.F90    54
# 1833                                 0.005151  flash4  hy_TVDslope.F90    54
#
#          procedure             type
# 1796  hy_tvdslope_  procedure frame
# 1814  hy_tvdslope_  procedure frame
# 1833  hy_tvdslope_  procedure frame

# %%
df.flame_graph(shape='wheel')
